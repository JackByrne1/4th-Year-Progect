# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
import io
Features = pd.read_csv(io.BytesIO(uploaded['Featuredata.csv']))
# Out:
#      <input type="file" id="files-a10e967a-8589-40ec-b034-007a9bfebe2a" name="files[]" multiple disabled />
#      <output id="result-a10e967a-8589-40ec-b034-007a9bfebe2a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Featuredata.csv to Featuredata.csv

# %%
from google.colab import files
uploaded = files.upload()
import io
KP = pd.read_csv(io.BytesIO(uploaded['KPdata.csv']))
# Out:
#      <input type="file" id="files-6ed741c2-0e9b-444f-bbcc-e521ee0c916b" name="files[]" multiple disabled />
#      <output id="result-6ed741c2-0e9b-444f-bbcc-e521ee0c916b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving KPdata.csv to KPdata.csv

# %%
Features.head(20)
# Out:
#       year    day         hr  ...     pos_gsm_x      pos_gsm_y     pos_gsm_z
# 0   2002.0  152.0   1.000000  ...  1.540000e+06  214416.666667  46880.952381
# 1   2002.0  152.0   4.000000  ...  1.542663e+06  217798.816568  19964.201183
# 2   2002.0  152.0   7.005917  ...  1.550000e+06  217911.242604  -8364.547929
# 3   2002.0  152.0  10.000000  ...  1.550000e+06  216327.380952 -22761.904762
# 4   2002.0  152.0  12.994083  ...  1.550000e+06  216390.532544 -13833.846154
# 5   2002.0  152.0  16.000000  ...  1.550000e+06  215378.698225  16220.391716
# 6   2002.0  152.0  19.005917  ...  1.550000e+06  210118.343195  47692.899408
# 7   2002.0  152.0  22.000000  ...  1.550000e+06  206315.476190  59828.571429
# 8   2002.0  153.0   0.994083  ...  1.550000e+06  208502.958580  48938.461538
# 9   2002.0  153.0   4.000000  ...  1.550000e+06  212218.934911  22691.360947
# 10  2002.0  153.0   7.005917  ...  1.550000e+06  212733.727811  -4932.979882
# 11  2002.0  153.0  10.000000  ...  1.550000e+06  211345.238095 -19010.119048
# 12  2002.0  153.0  12.994083  ...  1.550000e+06  211000.000000 -10296.178698
# 13  2002.0  153.0  16.000000  ...  1.550000e+06  209834.319527  19058.816568
# 14  2002.0  153.0  19.005917  ...  1.550000e+06  204171.597633  49744.970414
# 15  2002.0  153.0  22.000000  ...  1.550000e+06  200273.809524  61573.809524
# 16  2002.0  154.0   0.994083  ...  1.550000e+06  202562.130178  51008.284024
# 17  2002.0  154.0   4.000000  ...  1.550000e+06  206556.213018  25495.266272
# 18  2002.0  154.0   7.005917  ...  1.550000e+06  207621.301775  -1421.779290
# 19  2002.0  154.0  10.000000  ...  1.550000e+06  206357.142857 -15164.285714
#
# [20 rows x 34 columns]

# %%
df = pd.concat([Features, KP], axis=1)
df.head(30)
# Out:
#       year    day         hr        min  ...      pos_gsm_y     pos_gsm_z   Date  KP
# 0   2002.0  152.0   1.000000  29.869048  ...  214416.666667  46880.952381  20601   0
# 1   2002.0  152.0   4.000000  29.597633  ...  217798.816568  19964.201183  20601   0
# 2   2002.0  152.0   7.005917  29.502959  ...  217911.242604  -8364.547929  20601   1
# 3   2002.0  152.0  10.000000  29.607143  ...  216327.380952 -22761.904762  20601   1
# 4   2002.0  152.0  12.994083  29.692308  ...  216390.532544 -13833.846154  20601   0
# 5   2002.0  152.0  16.000000  29.597633  ...  215378.698225  16220.391716  20601   1
# 6   2002.0  152.0  19.005917  29.502959  ...  210118.343195  47692.899408  20601   1
# 7   2002.0  152.0  22.000000  29.607143  ...  206315.476190  59828.571429  20601   2
# 8   2002.0  153.0   0.994083  29.680473  ...  208502.958580  48938.461538  20602   4
# 9   2002.0  153.0   4.000000  29.579882  ...  212218.934911  22691.360947  20602   3
# 10  2002.0  153.0   7.005917  29.485207  ...  212733.727811  -4932.979882  20602   2
# 11  2002.0  153.0  10.000000  29.595238  ...  211345.238095 -19010.119048  20602   2
# 12  2002.0  153.0  12.994083  29.680473  ...  211000.000000 -10296.178698  20602   3
# 13  2002.0  153.0  16.000000  29.579882  ...  209834.319527  19058.816568  20602   3
# 14  2002.0  153.0  19.005917  29.485207  ...  204171.597633  49744.970414  20602   3
# 15  2002.0  153.0  22.000000  29.595238  ...  200273.809524  61573.809524  20602   4
# 16  2002.0  154.0   0.994083  29.692308  ...  202562.130178  51008.284024  20603   3
# 17  2002.0  154.0   4.000000  29.597633  ...  206556.213018  25495.266272  20603   3
# 18  2002.0  154.0   7.005917  29.502959  ...  207621.301775  -1421.779290  20603   2
# 19  2002.0  154.0  10.000000  29.607143  ...  206357.142857 -15164.285714  20603   1
# 20  2002.0  154.0  12.994083  29.692308  ...  206000.000000  -6663.386391  20603   2
# 21  2002.0  154.0  16.000000  29.597633  ...  204278.106509  21978.934911  20603   1
# 22  2002.0  154.0  19.005917  29.502959  ...  198207.100592  51878.698225  20603   3
# 23  2002.0  154.0  22.000000  29.607143  ...  194202.380952  63394.642857  20603   2
# 24  2002.0  155.0   0.994083  29.692308  ...  196585.798817  53155.029586  20604   3
# 25  2002.0  155.0   4.000000  29.597633  ...  200881.656805  28386.390533  20604   3
# 26  2002.0  155.0   7.005917  29.502959  ...  202000.000000   2179.673373  20604   4
# 27  2002.0  155.0  10.000000  29.607143  ...  201375.000000 -11236.815476  20604   3
# 28  2002.0  155.0  12.994083  29.680473  ...  201000.000000  -2948.943787  20604   3
# 29  2002.0  155.0  16.000000  29.579882  ...  198639.053254  24974.142012  20604   2
#
# [30 rows x 36 columns]

# %%
df = df.drop(['year','day','hr','min','sec','Date'],axis=1)

# %%
df = df[df['Np'].notna()]

# %%
df
# Out:
#              Np             Tp  Alpha_ratio  ...      pos_gsm_y     pos_gsm_z  KP
# 6     15.141382   28194.117647     0.028960  ...  210118.343195  47692.899408   1
# 7     19.522396   30309.226190     0.032599  ...  206315.476190  59828.571429   2
# 8     12.019873   84164.792899     0.034897  ...  208502.958580  48938.461538   4
# 9      9.990908  132960.650888     0.018821  ...  212218.934911  22691.360947   3
# 10    10.572882  137446.745562     0.016086  ...  212733.727811  -4932.979882   2
# ...         ...            ...          ...  ...            ...           ...  ..
# 1627  11.018899   53331.656805     0.061772  ...   36935.502959  76958.579882   2
# 1628  10.734402   33015.384615     0.080554  ...   31414.201183  79548.520710   2
# 1629   7.847125   13027.648810     0.119222  ...   19807.142857  83401.785714   3
# 1630   5.893024    9540.207101     0.181260  ...    7270.295858  85691.715976   2
# 1631   5.897719   10378.846154     0.141164  ...    -129.805976  86318.343195   2
#
# [1626 rows x 30 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X = df[['Np','Tp','Alpha_ratio','Vp','V_rtn_r','V_rtn_t','V_rtn_n','V_gse_x','V_gse_y','V_gse_z','V_gsm_x','V_gsm_y','V_gsm_z','B_rtn_r','B_rtn_t','B_rtn_n','B_gse_x','B_gse_y','B_gse_z','B_gsm_x','B_gsm_y','B_gsm_z','Bmag','pos_gse_x','pos_gse_y','pos_gse_z','pos_gsm_x','pos_gsm_y','pos_gsm_z']].values

# %%
Y = df[['KP']].values

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3,random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
 X_train = scaler.transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(29,activation='tanh'))
model.add(Dense(29,activation='relu'))
model.add(Dense(29,activation='tanh'))

model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
model.fit(x=X_train, y=Y_train, epochs=50)
# Out:
# Epoch 1/50
# 36/36 [==============================] - 0s 2ms/step - loss: 2.5121
# Epoch 2/50
# 36/36 [==============================] - 0s 1ms/step - loss: 1.5883
# Epoch 3/50
# 36/36 [==============================] - 0s 1ms/step - loss: 1.3580
# Epoch 4/50
# 36/36 [==============================] - 0s 1ms/step - loss: 1.1204
# Epoch 5/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.9361
# Epoch 6/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.8250
# Epoch 7/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.8170
# Epoch 8/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.7396
# Epoch 9/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.6790
# Epoch 10/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.6626
# Epoch 11/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.6442
# Epoch 12/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.6386
# Epoch 13/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.6427
# Epoch 14/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.6239
# Epoch 15/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.6369
# Epoch 16/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.6226
# Epoch 17/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.6089
# Epoch 18/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.6432
# Epoch 19/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.6040
# Epoch 20/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.6054
# Epoch 21/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.5977
# Epoch 22/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.6085
# Epoch 23/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.5835
# Epoch 24/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.5711
# Epoch 25/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.5951
# Epoch 26/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.5859
# Epoch 27/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.5869
# Epoch 28/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.5700
# Epoch 29/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.5740
# Epoch 30/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.5576
# Epoch 31/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.5510
# Epoch 32/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.5497
# Epoch 33/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.5561
# Epoch 34/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.5452
# Epoch 35/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.5398
# Epoch 36/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.5486
# Epoch 37/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.5498
# Epoch 38/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.5430
# Epoch 39/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.5310
# Epoch 40/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.5386
# Epoch 41/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.5437
# Epoch 42/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.5449
# Epoch 43/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.5205
# Epoch 44/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.5224
# Epoch 45/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.5235
# Epoch 46/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.5513
# Epoch 47/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.5266
# Epoch 48/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.5105
# Epoch 49/50
# 36/36 [==============================] - 0s 1ms/step - loss: 0.5163
# Epoch 50/50
# 36/36 [==============================] - 0s 2ms/step - loss: 0.5176

# %%
model.evaluate(X_test,Y_test,verbose=0)
# Out:
# 0.6418748497962952

# %%
testP = model.predict(X_test)
testP = pd.Series(testP.reshape(488,))
testP = testP.round(0)

# %%
pred_df = pd.DataFrame(Y_test,columns=['True Y'])

# %%
pred_df = pd.concat([pred_df,testP],axis=1)
pred_df.columns = ['True KP', 'Estimated KP']
pred_df.head(60)
# Out:
#     True KP  Estimated KP
# 0         4           4.0
# 1         3           3.0
# 2         3           2.0
# 3         2           2.0
# 4         3           3.0
# 5         2           2.0
# 6         3           2.0
# 7         1           1.0
# 8         1           1.0
# 9         2           2.0
# 10        1           0.0
# 11        1           1.0
# 12        2           2.0
# 13        2           2.0
# 14        2           2.0
# 15        1           2.0
# 16        2           2.0
# 17        2           2.0
# 18        3           2.0
# 19        6           4.0
# 20        1           2.0
# 21        3           2.0
# 22        2           2.0
# 23        2           2.0
# 24        3           3.0
# 25        1           2.0
# 26        3           4.0
# 27        1           1.0
# 28        1           2.0
# 29        2           2.0
# 30        1           1.0
# 31        4           4.0
# 32        1           1.0
# 33        1           1.0
# 34        1           1.0
# 35        5           5.0
# 36        3           2.0
# 37        3           3.0
# 38        1           1.0
# 39        0           1.0
# 40        2           2.0
# 41        3           2.0
# 42        1           1.0
# 43        1           1.0
# 44        3           2.0
# 45        2           2.0
# 46        7           6.0
# 47        4           2.0
# 48        3           2.0
# 49        3           3.0
# 50        2           2.0
# 51        0           1.0
# 52        0           0.0
# 53        1           1.0
# 54        3           2.0
# 55        5           4.0
# 56        2           2.0
# 57        6           3.0
# 58        1           1.0
# 59        3           3.0

# %%
pred_df.loc[pred_df['True KP'] == pred_df['Estimated KP']].count()
# Out:
# True KP         248
# Estimated KP    248
# dtype: int64

# %%
pred_df.plot(figsize=(35,5))
